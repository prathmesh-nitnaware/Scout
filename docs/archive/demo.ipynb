# %%
import pandas as pd

df = pd.read_parquet(
    "artifacts/candidate_features.parquet"
)

print(df.columns.tolist())

print(df.iloc[0].to_dict())
# Out:
# ['candidate_id', 'years_exp', 'current_title', 'location', 'country', 'skills', 'skills_count', 'education_tier', 'highest_degree', 'education_field', 'summary', 'career_text', 'raw_text', 'response_rate', 'activity_score', 'recruiter_saves', 'interview_completion_rate', 'salary_min', 'salary_max', 'notice_period_days', 'profile_completeness', 'github_score', 'open_to_work', 'willing_to_relocate', 'preferred_work_mode', 'num_jobs']
# ...
